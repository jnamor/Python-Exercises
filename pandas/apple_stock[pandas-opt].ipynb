# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple = pd.read_csv("data/appl_1980_2014.csv")
apple
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   object
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
# astype('datetime64[ns]'
apple['Date'] = pd.to_datetime(apple['Date'])

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple = apple.set_index(['Date'])
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple[apple.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Adj Close]
# Index: []

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple = apple.reset_index()
apple['year']= apple.Date.dt.year
apple['month']= apple.Date.dt.month
apple['day']= apple.Date.dt.day
apple = apple.set_index('Date')
apple
# Out:
#             index   Open   High    Low  Close     Volume  Adj Close  year  \
# Date
# 2014-07-08      0  96.27  96.80  93.92  95.35   65130000      95.35  2014
# 2014-07-07      1  94.14  95.99  94.10  95.97   56305400      95.97  2014
# 2014-07-03      2  93.67  94.10  93.20  94.03   22891800      94.03  2014
# 2014-07-02      3  93.87  94.06  93.09  93.48   28420900      93.48  2014
# 2014-07-01      4  93.52  94.07  93.13  93.52   38170200      93.52  2014
# ...           ...    ...    ...    ...    ...        ...        ...   ...
# 1980-12-18   8460  26.63  26.75  26.63  26.63   18362400       0.41  1980
# 1980-12-17   8461  25.87  26.00  25.87  25.87   21610400       0.40  1980
# 1980-12-16   8462  25.37  25.37  25.25  25.25   26432000       0.39  1980
# 1980-12-15   8463  27.38  27.38  27.25  27.25   43971200       0.42  1980
# 1980-12-12   8464  28.75  28.87  28.75  28.75  117258400       0.45  1980
#
#             month  day
# Date
# 2014-07-08      7    8
# ...

# %%
last_day_of_each_month = apple[['year', 'month', 'day']] \
                            .groupby(['year', 'month'], as_index=False) \
                            .max('day') \
                            .sort_values(['year', 'month'], ascending=False)

last_day_of_each_month
# Out:
#      year  month  day
# 403  2014      7    8
# 402  2014      6   30
# 401  2014      5   30
# 400  2014      4   30
# 399  2014      3   31
# ..    ...    ...  ...
# 4    1981      4   30
# 3    1981      3   31
# 2    1981      2   27
# 1    1981      1   30
# 0    1980     12   31
#
# [404 rows x 3 columns]

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
last_day_of_each_month['day'].sum()
# Out:
# 12084

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
last_day_of_each_month['month'].sum()
# Out:
# 2614

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(13.5,9))

plt.plot(apple.index, apple['Adj Close'], label='Adj Close value versus time')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Adj Close', fontsize=12)
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# ### How many years has it been exactly?

# %%
round(last_day_of_each_month['day'].sum() / 365, 3)
# Out:
# 33.107
